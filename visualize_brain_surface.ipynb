# %%
import pandas as pd
import numpy as np

# Add rpy2 to run R code chunks
# %load_ext rpy2.ipython

# %%
# %%R
#
# # Load packages needed for visualization in R
# suppressPackageStartupMessages({
#     library(cowplot)
#     library(tidyverse)
#     library(ggseg)
#     library(ggsegGlasser)
#     library(patchwork)
#
#     # Set cowplot theme
#     theme_set(theme_cowplot())
# })

# %%
# %%R
#
# data_to_plot <- glasser %>%
#     as_tibble() %>%
#     filter(str_detect(region, "V1|V2"))
#
# ggplot(data_to_plot, aes(fill=region)) +
#     geom_brain(atlas=glasser,
#               colour="gray70") +
#               theme_void() +
#     theme(legend.position = "none")
# Out:
# merging atlas and data by 'atlas', 'type', 'hemi', 'region', 'side', 'label', 'geometry'
